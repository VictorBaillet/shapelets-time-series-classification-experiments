# %% [markdown]
# # Shapelet visualization

# %% [markdown]
# This notebooks displays the most important shapelets for each dataset

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
file_path = "results/shapelets/ECG Five Days_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
for i in range(10):
    plt.plot(data[i])
plt.grid(True)
plt.xlabel("Time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
file_path = "results/shapelets/ECG200_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
plt.plot(data[0])

# %%
file_path = "results/shapelets/GunPointAgeSpan_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
for i in range(2):
    plt.plot(data[i])

# %%
file_path = "results/shapelets/Mote Strain_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
plt.plot(data[8])

# %%
file_path = "results/shapelets/Sony Robot_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
plt.plot(data[6])

# %%
file_path = "results/shapelets/Two Lead ECG_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
plt.plot(data[5])

# %%
file_path = "results/shapelets/Beef_F_stat.json"

with open(file_path, 'r') as file:
    data = json.load(file)

# %%
plt.plot(data[7])
